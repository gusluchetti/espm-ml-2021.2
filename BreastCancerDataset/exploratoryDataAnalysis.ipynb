# %%
import pandas as pd
# reading csv and removing useless columns
df = pd.read_csv("https://raw.githubusercontent.com/fbarth/ml-espm/master/dataset/breast-cancer-wisconsin.csv")
df = df.drop(columns=['id', 'Unnamed: 32'])
df = df.replace("M", "bad")
df = df.replace("B", "good")
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0       bad        17.99         10.38          122.80     1001.0
# 1       bad        20.57         17.77          132.90     1326.0
# 2       bad        19.69         21.25          130.00     1203.0
# 3       bad        11.42         20.38           77.58      386.1
# 4       bad        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# # Data Analysis

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
# no null values

sns.set_theme(style="dark")
sns.set_palette("colorblind")

sns.histplot(
    data=df,
    x="radius_mean", hue="diagnosis",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False,
)

# mean radius over 17.5 usually means malignant cancer
# Out:
# <AxesSubplot:xlabel='radius_mean', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="dark")
sns.set_palette("colorblind")

sns.histplot(
    data=df,
    x="smoothness_mean", hue="diagnosis",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False,
)
# Out:
# <AxesSubplot:xlabel='smoothness_mean', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="dark")
sns.set_palette("colorblind")

sns.scatterplot(
    data=df, 
    x="radius_mean", 
    y="smoothness_mean", 
    hue="diagnosis")
# Out:
# <AxesSubplot:xlabel='radius_mean', ylabel='smoothness_mean'>

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="dark")
sns.set_palette("colorblind")

sns.scatterplot(
    data=df, 
    x="area_mean", 
    y="symmetry_mean", 
    hue="diagnosis")
# Out:
# <AxesSubplot:xlabel='area_mean', ylabel='symmetry_mean'>

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="dark")
sns.set_palette("colorblind")

sns.displot(
    data=df, 
    kind="hist", 
    height=5,
    x="area_worst", 
    y="perimeter_worst", 
    hue="diagnosis")

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="dark")
sns.set_palette("colorblind")

sns.histplot(
    data=df,
    x="concavity_mean", hue="diagnosis",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    log_scale=False,
)
# Out:
# <AxesSubplot:xlabel='concavity_mean', ylabel='Count'>

# %% [markdown]
# ## Separating dataset into training and validation datasets

# %%
from sklearn.model_selection import train_test_split

# no specific data processing will be done, that is repeated on every single pipeline for better maintenance
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,1:df.size-2], df['diagnosis'], test_size=0.1, random_state=4)

#training datasets
X_train.to_csv(path_or_buf="training_datasets/base_train.csv")
y_train.to_csv(path_or_buf="training_datasets/base_train_answer.csv")

#validating datasets
X_test.to_csv(path_or_buf="validating_datasets/base_test.csv")
y_test.to_csv(path_or_buf="validating_datasets/base_test_answer.csv")
